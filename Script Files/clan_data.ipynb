# %%
import os
import json
import pytz
import requests
import pandas as pd
from datetime import datetime, timedelta

# Get your current public IP address
response = requests.get('https://api.ipify.org?format=json')
if response.status_code == 200:
    current_ip = response.json()['ip']
    print(f"Your current IP address is: {current_ip}")
else:
    print(f"Error fetching current IP address: {response.status_code}")
# Out:
# Your current IP address is: 49.35.138.63

# %%
# Clash of Clans API token
""" For IP: 49.35.138.63 """
API_TOKEN = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiIsImtpZCI6IjI4YTMxOGY3LTAwMDAtYTFlYi03ZmExLTJjNzQzM2M2Y2NhNSJ9..tuVGGEUQqno8NLkbur_Lf-4IggW7TntAszjvDZfirPJgO6bivhlYJgqAF_nlyLiegAXPQU-GtAVch1T1ROn6vw"

# Base URL for Clash of Clans API
BASE_URL = "https://api.clashofclans.com/v1"
clan_tag =  "V9J82LUC"  #"U08RLVCV"

# Get the current date
current_date = datetime.now().strftime("%Y-%m-%d")
print(f"Current Date is: {current_date}")
# Out:
# Current Date is: 2024-07-19

# %% [markdown]
# ## **Clan Data**

# %% [markdown]
# #### *JSON File + Excel File*

# %%
# Define the folder path and ensure it exists
folder_path = r'D:\\Python Data\\Projects\\Fukre Work\\Clash of Clan Data\\Clan Data'
os.makedirs(folder_path, exist_ok=True)
game_folder_path = r'D:\\Python Data\\Projects\\Fukre Work\\Clash of Clan Data'
os.makedirs(game_folder_path, exist_ok=True)

# Fetch clan data
url = f"{BASE_URL}/clans/%23{clan_tag}"
headers = {"Authorization": f"Bearer {API_TOKEN}"}

response = requests.get(url, headers=headers)
if response.status_code == 200:
    clan_data = response.json()
    print(json.dumps(clan_data, indent=4, ensure_ascii=False))

    # Save clan data to JSON file with UTF-8 encoding
    json_filename = os.path.join(folder_path, f"{current_date}_clan_data.json")
    with open(json_filename, "w", encoding="utf-8") as json_file:
        json.dump(clan_data, json_file, indent=4, ensure_ascii=False)
        print(f"Clan data saved to '{json_filename}'")

    # Extract relevant data
    extracted_data = {
        "Clan Tag": clan_data.get("tag"),
        "Clan Name": clan_data.get("name"),
        "Clan Type": clan_data.get("type"),
        "Clan Description": clan_data.get("description"),
        "Location": clan_data.get("location", {}).get("name"),
        "Clan Level": clan_data.get("clanLevel"),
        "Clan Points": clan_data.get("clanPoints"),
        "Clan Builder Base Points": clan_data.get("clanBuilderBasePoints"),
        "Clan Capital Points": clan_data.get("clanCapitalPoints"),
        "War League": clan_data.get("warLeague", {}).get("name"),
        "Capital League": clan_data.get("capitalLeague", {}).get("name"),
        "Required Trophies": clan_data.get("requiredTrophies"),
        "War Frequency": clan_data.get("warFrequency"),
        "War Win Streak": clan_data.get("warWinStreak"),
        "War Wins": clan_data.get("warWins"),
        "War Losses": clan_data.get("warLosses"),
        "War Ties": clan_data.get("warTies"),
        "WarLog Public": clan_data.get("isWarLogPublic"),
        "Total Members": clan_data.get("members"),
        "Clan Labels": ", ".join(label["name"] for label in clan_data.get("labels", [])),
        "Chat Language": clan_data.get("chatLanguage", {}).get("name")
    }

    # Prepare the data for vertical layout
    keys = list(extracted_data.keys())
    values = list(extracted_data.values())

    # Convert to DataFrame
    df = pd.DataFrame({'Key': keys, 'Value': values})

    # Save to Excel
    current_date = datetime.now().strftime("%Y-%m-%d")
    excel_filename = os.path.join(folder_path, f"{current_date}_clan_data.xlsx")
    excel_filename1 = os.path.join(game_folder_path, "Clan_Data.xlsx")
    df.to_excel(excel_filename, index=False, header=False)
    df.to_excel(excel_filename1, index=False, header=False)

    print(f"Clan data saved to '{excel_filename}'")
else:
    print(f"Error fetching clan data: {response.status_code} - {response.text}")
# Out:
# {
#     "tag": "#V9J82LUC",
#     "name": "WarHurricanes",
#     "type": "open",
#     "description": "जय श्री राम 🚩                                                                                                                                          Recruiting Th16 with good attacking skills ✅",
#     "location": {
#         "id": 32000113,
#         "name": "India",
#         "isCountry": true,
#         "countryCode": "IN"
#     },
#     "isFamilyFriendly": false,
#     "badgeUrls": {
#         "small": "https://api-assets.clashofclans.com/badges/70/torM-qpSS-8CqRiYuq8h8myuh3xdg7SLBfYpfRpBT_Q.png",
#         "large": "https://api-assets.clashofclans.com/badges/512/torM-qpSS-8CqRiYuq8h8myuh3xdg7SLBfYpfRpBT_Q.png",
#         "medium": "https://api-assets.clashofclans.com/badges/200/torM-qpSS-8CqRiYuq8h8myuh3xdg7SLBfYpfRpBT_Q.png"
#     },
#     "clanLevel": 17,
#     "clanPoints": 41604,
#     "clanBuilderBasePoints": 38199,
#     "clanCapitalPoints": 1413,
# ...

# %% [markdown]
# ## **Players Data**

# %%
# Define the folder path and ensure it exists
players_folder_path = r'D:\\Python Data\\Projects\\Fukre Work\\Clash of Clan Data\\Players Data'
os.makedirs(players_folder_path, exist_ok=True)
game_folder_path = r'D:\\Python Data\\Projects\\Fukre Work\\Clash of Clan Data'
os.makedirs(game_folder_path, exist_ok=True)

# Fetch clan data
url = f"{BASE_URL}/clans/%23{clan_tag}"
headers = {"Authorization": f"Bearer {API_TOKEN}"}

response = requests.get(url, headers=headers)
if response.status_code == 200:
    clan_data = response.json()
else:
    print(f"Error fetching clan data: {response.status_code} - {response.text}")
    clan_data = None

# Convert clan data to DataFrame
if clan_data:
    members = clan_data.get('memberList', [])
    data = []
    for member in members:
        # Replace 'admin' with 'Elder' in Role
        role = member.get('role', '')
        if role == 'admin':
            role = 'elder'
        
        # Calculate Donation Ratio as percentage
        donated = member.get('donations', 0)
        received = member.get('donationsReceived', 0)
        if received != 0:
            donation_ratio = round((donated / received) * 100, 2)
        else:
            donation_ratio = 0
        
        # Limit ratio to 100% if Troops Donated value is equal to or more than Troops Received
        if donated >= received:
            donation_ratio = 100
        
        data.append({
            "Clan Rank":member.get('clanRank', ''),
            "Player Tag": member.get('tag', ''),
            "Player Name": member.get('name', ''),
            "Role": role,
            "Town Hall Level": member.get('townHallLevel', ''),
            "EXP Level": member.get('expLevel', ''),
            "Home Base Trophies": member.get('trophies', ''),
            "Builder Base Trophies": member.get('builderBaseTrophies', ''),
            "Troops Donated": donated,
            "Troops Received": received,
            "Donation Ratio (%)": donation_ratio
        })
        
    df = pd.DataFrame(data)
    print(df)
    # Save to Excel
    players_excel_filename = os.path.join(players_folder_path, f"{current_date}_clan_players_data.xlsx")
    df.to_excel(players_excel_filename, index=False)

    # Sort the consolidated DataFrame by 'Name' in a case-insensitive manner
    df1 = df.sort_values(by='Player Name', key=lambda x: x.str.lower())
    players_excel_filename1 = os.path.join(game_folder_path, "Players_Data.xlsx")
    df1.to_excel(players_excel_filename1, index=False)
    print(f"Raid data saved to {current_date}_clan_players_data.xlsx")
else:
    # Print error message if request failed
    print(f"Error fetching data: {response.status_code} - {response.text}")
# Out:
#     Clan Rank  Player Tag      Player Name      Role  Town Hall Level  \
# 0           1  #2LRPC8U0Q           MaTiaS    leader               16
# 1           2  #9YVG90CUU            Dhrxv     elder               16
# 2           3  #LVLVCU0JP   New Gabber Boy     elder               15
# 3           4  #22QCPVUGL           ayyoob     elder               16
# 4           5  #LV9QL9C0Y     satyam Raj $  coLeader               15
# 5           6  #P0QYRL09V              RDX    member               14
# 6           7  #PV2VY8U8Y           Prince     elder               16
# 7           8  #PY9LUQCGJ            Vikas     elder               16
# 8           9    #8LRURLP            rishi  coLeader               16
# 9          10  #LC2QRQ88G        rishi raj    member               15
# 10         11  #LJ8J928JJ            Dimpu     elder               16
# 11         12   #LL8098L0             yogi     elder               16
# ...

# %% [markdown]
# ## **Raid Weekend Data**

# %% [markdown]
# #### *Excel File*

# %%
# Define the folder path and ensure it exists
raid_folder_path = r'D:\\Python Data\\Projects\\Fukre Work\\Clash of Clan Data\\Raid Weekend Data'
os.makedirs(raid_folder_path, exist_ok=True)

# Endpoint URL
url = f"{BASE_URL}/clans/%23{clan_tag}/capitalraidseasons"
headers = {"Authorization": f"Bearer {API_TOKEN}"}

# Send GET request to the API endpoint
response = requests.get(url, headers=headers)

# Check if request was successful (status code 200)
if response.status_code == 200:
    # Parse response JSON data
    data = response.json()
    
    # Extract members data
    members_data = []
    for item in data.get("items", []):
        start_time_utc = datetime.strptime(item.get("startTime"), "%Y%m%dT%H%M%S.%fZ")
        end_time_utc = datetime.strptime(item.get("endTime"), "%Y%m%dT%H%M%S.%fZ")
        
        # Convert start and end times to IST
        ist = pytz.timezone("Asia/Kolkata")
        start_time_ist = start_time_utc.replace(tzinfo=pytz.utc).astimezone(ist)
        end_time_ist = end_time_utc.replace(tzinfo=pytz.utc).astimezone(ist)
        
        for member in item.get("members", []):
            # Calculate week number based on start time
            week_number = start_time_ist.isocalendar()[1]
            
            member_data = {
                "Start Time (IST)": start_time_ist.strftime("%Y-%m-%d %H:%M:%S"),
                "End Time (IST)": end_time_ist.strftime("%Y-%m-%d %H:%M:%S"),
                "Week Number": week_number,
                "Player Tag": member.get("tag"),
                "Player Name": member.get("name"),
                "Attacks": member.get("attacks"),
                "Attack Limit": member.get("attackLimit"),
                "Bonus Attack Limit": member.get("bonusAttackLimit"),
                "Capital Resources Looted": member.get("capitalResourcesLooted")
            }
            members_data.append(member_data)
    
    # Convert members data to DataFrame
    df = pd.DataFrame(members_data)
    print(df)
    # Save to Excel
    excel_filename = os.path.join(raid_folder_path, f"{week_number}_raid_weekend_data.xlsx")
    df.to_excel(excel_filename, index=False)
    print(f"Raid data saved to {week_number}_raid_weekend_data.xlsx")
else:
    # Print error message if request failed
    print(f"Error fetching data: {response.status_code} - {response.text}")
# Out:
#       Start Time (IST)       End Time (IST)  Week Number  Player Tag  \
# 0  2024-07-19 12:30:00  2024-07-22 12:30:00           29  #9YVG90CUU
# 1  2024-07-19 12:30:00  2024-07-22 12:30:00           29  #8JU9RUPYR
# 2  2024-07-19 12:30:00  2024-07-22 12:30:00           29  #LV9QL9C0Y
#
#     Player Name  Attacks  Attack Limit  Bonus Attack Limit  \
# 0         Dhrxv        1             5                   0
# 1       XOKANTA        6             5                   1
# 2  satyam Raj $        6             5                   1
#
#    Capital Resources Looted
# 0                      3670
# 1                     20423
# 2                     20705
# Raid data saved to 29_raid_weekend_data.xlsx

# %% [markdown]
# #### *JSON File*

# %%
# Check if request was successful (status code 200)
if response.status_code == 200:
    raid_data = response.json()
    print(json.dumps(raid_data, indent=4, ensure_ascii=False)) 

    # Save raid weekend data to JSON file with UTF-8 encoding
    json_filename = os.path.join(raid_folder_path, f"{week_number}_raid_weekend_data.json")
    with open(json_filename, "w", encoding="utf-8") as json_file:
        json.dump(raid_data, json_file, indent=4, ensure_ascii=False)
        print(f"Raid weekend data saved to '{json_filename}'")
else:
    print(f"Error fetching raid weekend data: {response.status_code} - {response.text}")
# Out:
# {
#     "items": [
#         {
#             "state": "ongoing",
#             "startTime": "20240719T070000.000Z",
#             "endTime": "20240722T070000.000Z",
#             "capitalTotalLoot": 44798,
#             "raidsCompleted": 0,
#             "totalAttacks": 13,
#             "enemyDistrictsDestroyed": 5,
#             "offensiveReward": 0,
#             "defensiveReward": 0,
#             "members": [
#                 {
#                     "tag": "#9YVG90CUU",
#                     "name": "Dhrxv",
#                     "attacks": 1,
#                     "attackLimit": 5,
#                     "bonusAttackLimit": 0,
#                     "capitalResourcesLooted": 3670
#                 },
#                 {
#                     "tag": "#8JU9RUPYR",
#                     "name": "XOKANTA",
#                     "attacks": 6,
#                     "attackLimit": 5,
#                     "bonusAttackLimit": 1,
#                     "capitalResourcesLooted": 20423
# ...

# %% [markdown]
# ## **All Previous War Data**

# %%
# Define the folder path and ensure it exists
all_war_folder_path = r'D:\\Python Data\\Projects\\Fukre Work\\Clash of Clan Data\\All Wars Data'
game_folder_path = r'D:\\Python Data\\Projects\\Fukre Work\\Clash of Clan Data'
os.makedirs(all_war_folder_path, exist_ok=True)
os.makedirs(game_folder_path, exist_ok=True)

# Fetch war log data
url = f"{BASE_URL}/clans/%23{clan_tag}/warlog"
headers = {"Authorization": f"Bearer {API_TOKEN}"}

response = requests.get(url, headers=headers)
if response.status_code == 200:
    war_log_data = response.json()
else:
    print(f"Error fetching war log data: {response.status_code} - {response.text}")
    war_log_data = None

# Extract all previous war data
if war_log_data:
    wars = war_log_data.get('items', [])
    data = []
    for war in wars:
        opponent_clan_name = war['opponent'].get('name', 'N/A')
        if opponent_clan_name != 'N/A':
            end_time_utc = war.get('endTime', 'N/A')
            if end_time_utc != 'N/A':
                end_time_utc = datetime.strptime(end_time_utc, "%Y%m%dT%H%M%S.%fZ")
                end_time_utc = end_time_utc.replace(tzinfo=pytz.utc)
                end_time_ist = end_time_utc.astimezone(pytz.timezone('Asia/Kolkata'))
                end_time_ist = end_time_ist.strftime("%Y-%m-%d %H:%M:%S")
            else:
                end_time_ist = 'N/A'

            war_data = {
                "Clan Tag": war['clan'].get('tag', 'N/A'),
                "Clan Name": war['clan'].get('name', 'N/A'),
                "Clan Level": war['clan'].get('clanLevel', 'N/A'),
                "Opponent Clan Tag": war['opponent'].get('tag', 'N/A'),
                "Opponent Clan Name": opponent_clan_name,
                "Opponent Clan Level": war['opponent'].get('clanLevel', 'N/A'),
                "Team Size": war.get('teamSize', 'N/A'),
                "Attacks Per Member": war.get('attacksPerMember', 'N/A'),
                "Total Clan Attacks": war['clan'].get('attacks', 'N/A'),
                "Clan Stars": war['clan'].get('stars', 'N/A'),
                "Clan Destruction Percentage": war['clan'].get('destructionPercentage', 'N/A'),
                "Exp Earned": war['clan'].get('expEarned', 'N/A'),
                "Opponent Clan Stars": war['opponent'].get('stars', 'N/A'),
                "Opponent Clan Destruction Percentage": war['opponent'].get('destructionPercentage', 'N/A'),
                "End Time": end_time_ist,
                "Result": war.get('result', 'N/A')
            }
            data.append(war_data)
    
    # Convert to DataFrame
    df = pd.DataFrame(data)
    print(df)
    
    # Save to Excel
    excel_file_name = os.path.join(all_war_folder_path, f"{current_date}_all_previous_war_data.xlsx")
    df.to_excel(excel_file_name, index=False)
    oa_file_name = os.path.join(game_folder_path, "previous_war_data.xlsx")
    df.to_excel(oa_file_name, index=False)
    print(f"All previous war data saved to '{excel_file_name}'")
else:
    print("Failed to retrieve data.")
# Out:
#       Clan Tag      Clan Name  Clan Level Opponent Clan Tag  \
# 0    #V9J82LUC  WarHurricanes          17        #208Y9YC0Y
# 1    #V9J82LUC  WarHurricanes          17         #VPQJ8GY2
# 2    #V9J82LUC  WarHurricanes          17        #2Y89CLGGL
# 3    #V9J82LUC  WarHurricanes          17        #2L8C9GP8Y
# 4    #V9J82LUC  WarHurricanes          17         #2YR9VLL2
# ..         ...            ...         ...               ...
# 99   #V9J82LUC  WarHurricanes          11         #J0P20UQU
# 100  #V9J82LUC  WarHurricanes          11         #GLGPCGYL
# 101  #V9J82LUC  WarHurricanes          11         #YUG00PV0
# 102  #V9J82LUC  WarHurricanes          11         #J09JLQY2
# 103  #V9J82LUC  WarHurricanes           1         #P8L8GQ9Y
#
#     Opponent Clan Name  Opponent Clan Level  Team Size Attacks Per Member  \
# 0          ENGELSİZLER                   28         30                  2
# 1         INDIAN FORCE                   19         30                  2
# ...

# %% [markdown]
# ## **Current War Data**

# %% [markdown]
# #### *Json File + Excel File*

# %%
# Define the folder path and ensure it exists
current_war_folder_path = r'D:\\Python Data\\Projects\\Fukre Work\\Clash of Clan Data\\Current War Data'
os.makedirs(current_war_folder_path, exist_ok=True)

# Endpoint URL
url = f"{BASE_URL}/clans/%23{clan_tag}/currentwar"
headers = {"Authorization": f"Bearer {API_TOKEN}"}

# Send GET request to the API endpoint
response = requests.get(url, headers=headers)

# Check if request was successful (status code 200)
if response.status_code == 200:
    # Parse response JSON data
    data = response.json()
    print(json.dumps(data, indent=4, ensure_ascii=False))

    # Check the war state
    state = data.get("state")
    if state == "notInWar":
        print("Clan not in daily war")
    else:
        # Extract the preparation start time
        preparation_start_time = data.get("preparationStartTime")
        
        # Convert to IST
        def convert_to_ist(iso_time):
            utc_time = datetime.strptime(iso_time, "%Y%m%dT%H%M%S.%fZ")
            utc_time = utc_time.replace(tzinfo=pytz.utc)
            ist_time = utc_time.astimezone(pytz.timezone('Asia/Kolkata'))
            return ist_time.strftime("%Y-%m-%d")
        
        preparation_start_time_ist = convert_to_ist(preparation_start_time)
        
        # Define file name
        file_name = os.path.join(current_war_folder_path, f"{preparation_start_time_ist}_current_war_data.json")
        
        # Save the data to a JSON file
        with open(file_name, "w", encoding="utf-8") as json_file:
            json.dump(data, json_file, indent=4, ensure_ascii=False)
            print(f"Current war data saved to '{file_name}'")
        
        # Extract members data
        members_data = []
        for member in data["clan"]["members"]:
            member_info = {
                "War Start Date": preparation_start_time_ist,
                "Tag": member.get("tag"),
                "Name": member.get("name"),
                "Townhall Level": member.get("townhallLevel"),
                "Map Position": member.get("mapPosition"),
                "Attack 1 Defender Tag": '',
                "Attack 1 Stars": '0',
                "Attack 1 Destruction Percentage": '0',
                "Attack 1 Duration": '0',
                "Attack 2 Defender Tag": '',
                "Attack 2 Stars": '0',
                "Attack 2 Destruction Percentage": '0',
                "Attack 2 Duration": '0'
            }
            
            attacks = member.get("attacks", [])
            if attacks:
                for i, attack in enumerate(attacks):
                    if i == 0:
                        member_info["Attack 1 Defender Tag"] = attack.get("defenderTag", '')
                        member_info["Attack 1 Stars"] = attack.get("stars", '')
                        member_info["Attack 1 Destruction Percentage"] = attack.get("destructionPercentage", '')
                        member_info["Attack 1 Duration"] = attack.get("duration", '')
                    elif i == 1:
                        member_info["Attack 2 Defender Tag"] = attack.get("defenderTag", '')
                        member_info["Attack 2 Stars"] = attack.get("stars", '')
                        member_info["Attack 2 Destruction Percentage"] = attack.get("destructionPercentage", '')
                        member_info["Attack 2 Duration"] = attack.get("duration", '')
            
            members_data.append(member_info)
        
        # Convert members data to DataFrame
        df = pd.DataFrame(members_data)
        # Sort the DataFrame by 'Map Position' in ascending order
        df = df.sort_values(by="Map Position")
        print(df)
        
        # Save to Excel
        excel_file_name = os.path.join(current_war_folder_path, f"{preparation_start_time_ist}_current_war_data.xlsx")
        df.to_excel(excel_file_name, index=False)
        print(f"Raid data saved to '{excel_file_name}'")
else:
    # Print error message if request failed
    print(f"Error fetching data: {response.status_code} - {response.text}")
# Out:
# {
#     "state": "inWar",
#     "teamSize": 25,
#     "attacksPerMember": 2,
#     "battleModifier": "none",
#     "preparationStartTime": "20240717T173900.000Z",
#     "startTime": "20240718T163900.000Z",
#     "endTime": "20240719T163900.000Z",
#     "clan": {
#         "tag": "#V9J82LUC",
#         "name": "WarHurricanes",
#         "badgeUrls": {
#             "small": "https://api-assets.clashofclans.com/badges/70/torM-qpSS-8CqRiYuq8h8myuh3xdg7SLBfYpfRpBT_Q.png",
#             "large": "https://api-assets.clashofclans.com/badges/512/torM-qpSS-8CqRiYuq8h8myuh3xdg7SLBfYpfRpBT_Q.png",
#             "medium": "https://api-assets.clashofclans.com/badges/200/torM-qpSS-8CqRiYuq8h8myuh3xdg7SLBfYpfRpBT_Q.png"
#         },
#         "clanLevel": 17,
#         "attacks": 26,
#         "stars": 56,
#         "destructionPercentage": 83.36,
#         "members": [
#             {
#                 "tag": "#2RVUPULYC",
#                 "name": "SOURABH",
# ...

# %% [markdown]
# ## *Data Processing*

# %% [markdown]
# ### OverAll Raid Data

# %%
import pandas as pd
import os
import glob

# Directory containing the raid weekend data files
input_folder = r'D:\\Python Data\\Projects\\Fukre Work\\Clash of Clan Data\\Raid Weekend Data'
output_file = r'D:\\Python Data\\Projects\\Fukre Work\\Clash of Clan Data\\Raid_data.xlsx'

# Get all Excel files in the directory
excel_files = glob.glob(os.path.join(input_folder, '*.xlsx'))

# Initialize an empty DataFrame to hold the consolidated data
consolidated_df = pd.DataFrame()

# Iterate over each Excel file
for file in excel_files:
    # Read the Excel file into a DataFrame
    df = pd.read_excel(file)
    
    # Extract the week number from the file name
    week_number = os.path.basename(file).split('_')[0]
    
    # Create a new column name for attacks based on the week number
    new_column_name = f'Week: {week_number}'
    
    # Select the necessary columns and rename the attacks column
    df = df[['Player Tag', 'Player Name', 'Attacks']].rename(columns={'Attacks': new_column_name})
    
    # Merge the current file's data with the consolidated DataFrame
    if consolidated_df.empty:
        consolidated_df = df
    else:
        consolidated_df = pd.merge(consolidated_df, df, on=['Player Tag', 'Player Name'], how='outer')

# Sort the consolidated DataFrame by 'Player Name' in a case-insensitive manner
consolidated_df = consolidated_df.sort_values(by='Player Name', key=lambda x: x.str.lower())

# Write the consolidated data to a new Excel file
consolidated_df.to_excel(output_file, index=False)

print(f"Consolidated data saved to {output_file}")
# Out:
# Consolidated data saved to D:\\Python Data\\Projects\\Fukre Work\\Clash of Clan Data\\Raid_data.xlsx

# %% [markdown]
# ### OverAll Daily War Data

# %%
import pandas as pd
import os
import glob

# Directory containing the current war data files
input_folder = r'D:\\Python Data\\Projects\\Fukre Work\\Clash of Clan Data\\Current War Data'
output_file = r'D:\\Python Data\\Projects\\Fukre Work\\Clash of Clan Data\\War_data.xlsx'

# Get all Excel files in the directory
excel_files = glob.glob(os.path.join(input_folder, '*.xlsx'))

# Initialize an empty list to hold the dataframes
dataframes = []

# Iterate over each Excel file
for file in excel_files:
    # Read the Excel file into a DataFrame
    df = pd.read_excel(file)
    
    # Extract the war start date from the file name
    war_start_date = os.path.basename(file).split('_')[0]
    
    # Select the necessary columns
    df = df[['Tag', 'Name', 'Attack 1 Stars', 'Attack 1 Destruction Percentage', 'Attack 2 Stars', 'Attack 2 Destruction Percentage']]
    
    # Rename the attack columns to include the war start date
    df = df.rename(columns={
        'Attack 1 Stars': f'{war_start_date} Attack 1 Stars',
        'Attack 1 Destruction Percentage': f'{war_start_date} Attack 1 DP',
        'Attack 2 Stars': f'{war_start_date} Attack 2 Stars',
        'Attack 2 Destruction Percentage': f'{war_start_date} Attack 2 DP'
    })
    
    # Append the DataFrame to the list
    dataframes.append(df)

# Merge all dataframes on 'Tag', 'Name', and 'Townhall Level'
consolidated_df = dataframes[0]
for df in dataframes[1:]:
    consolidated_df = pd.merge(consolidated_df, df, on=['Tag', 'Name'], how='outer')

# Sort the consolidated DataFrame by 'Name' in a case-insensitive manner
consolidated_df = consolidated_df.sort_values(by='Name', key=lambda x: x.str.lower())

# Write the consolidated data to a new Excel file
consolidated_df.to_excel(output_file, index=False)

print(f"Consolidated data saved to {output_file}")
# Out:
# Consolidated data saved to D:\\Python Data\\Projects\\Fukre Work\\Clash of Clan Data\\War_data.xlsx
